# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta

# %%
stock = 'AAPL'
start_date = '2022-01-01'
end_date = '2024-06-01'
data = yf.download(stock, start_date, end_date)
mean_open_prices = data.groupby(data.index.day).Open.mean()
min_day = mean_open_prices.idxmin()
print(min_day)
mean_open_prices
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 23
# Date
# 1     167.084286
# 2     165.958947
# 3     164.928499
# 4     167.042940
# 5     169.136844
# 6     165.557619
# 7     166.291428
# 8     167.453182
# 9     164.834999
# 10    164.089500
# 11    167.018501
# 12    167.905500
# 13    164.597619
# 14    166.201363
# 15    167.279501
# 16    165.893686
# 17    164.485790
# 18    167.715501
# 19    165.051668
# 20    167.257893
# 21    166.994763
# 22    168.240909
# 23    163.067895
# 24    165.791053
# 25    165.686315
# 26    168.517370
# 27    163.129002
# 28    166.599090
# 29    168.777221
# 30    166.433126
# 31    171.133847
# Name: Open, dtype: float64

# %%
aapl = yf.Ticker('AAPL')
aapl_options = aapl.option_chain('2024-07-05')
aapl_options
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL240705C00100000 2024-06-05 16:04:44+00:00   100.0      96.80  108.50
# 1   AAPL240705C00110000 2024-06-18 16:38:47+00:00   110.0     104.15   98.50
# 2   AAPL240705C00140000 2024-06-24 14:11:07+00:00   140.0      69.30   68.55
# 3   AAPL240705C00145000 2024-06-21 18:32:21+00:00   145.0      65.84   63.45
# 4   AAPL240705C00150000 2024-06-25 16:04:36+00:00   150.0      60.37   58.55
# 5   AAPL240705C00155000 2024-06-06 15:19:01+00:00   155.0      41.55   53.55
# 6   AAPL240705C00160000 2024-06-21 18:23:20+00:00   160.0      51.00   48.30
# 7   AAPL240705C00165000 2024-06-21 19:56:59+00:00   165.0      43.21   43.55
# 8   AAPL240705C00170000 2024-06-25 17:18:56+00:00   170.0      40.12   38.65
# 9   AAPL240705C00175000 2024-06-25 14:53:00+00:00   175.0      35.04   33.65
# 10  AAPL240705C00180000 2024-06-25 14:38:09+00:00   180.0      30.30   28.70
# 11  AAPL240705C00185000 2024-06-25 18:28:14+00:00   185.0      24.40   23.70
# 12  AAPL240705C00187500 2024-06-25 14:45:11+00:00   187.5      22.56   21.20
# 13  AAPL240705C00190000 2024-06-25 18:33:06+00:00   190.0      19.45   19.15
# 14  AAPL240705C00192500 2024-06-24 16:47:17+00:00   192.5      18.25   16.60
# 15  AAPL240705C00195000 2024-06-25 19:50:45+00:00   195.0      15.10   14.35
# 16  AAPL240705C00197500 2024-06-25 19:11:05+00:00   197.5      13.25   11.95
# 17  AAPL240705C00200000 2024-06-25 19:55:53+00:00   200.0      10.10    9.80
# 18  AAPL240705C00202500 2024-06-25 19:47:23+00:00   202.5       7.57    6.80
# 19  AAPL240705C00205000 2024-06-25 19:59:04+00:00   205.0       5.75    5.55
# 20  AAPL240705C00207500 2024-06-25 19:59:59+00:00   207.5       3.85    3.65
# 21  AAPL240705C00210000 2024-06-25 19:59:59+00:00   210.0       2.55    2.43
# 22  AAPL240705C00212500 2024-06-25 19:59:59+00:00   212.5       1.47    1.46
# 22    1.50 -0.100000      -6.369428   8764.0          5366           0.208260
# 23    0.85 -0.070000      -7.608695  26776.0         14661           0.207161
# 24    0.51 -0.060000     -10.526316   3750.0          6704           0.215096
# 25    0.29 -0.060000     -17.142857  12939.0         18317           0.220711
# 26    0.19 -0.030000     -13.043478   2160.0          2844           0.233894
# 27    0.14 -0.020000     -14.285716   1227.0          5259           0.250984
# 28    0.10 -0.010000      -9.999997    230.0          2106           0.265632
# 29    0.09  0.000000       0.000000   7798.0         12842           0.289070
# 30    0.07  0.000000       0.000000    115.0           317           0.304694
# 31    0.06  0.000000       0.000000    302.0          2642           0.322272
# 32    0.05  0.000000       0.000000     65.0           263           0.339850
# 33    0.05  0.000000       0.000000    219.0         12526           0.363288
# 34    0.04 -0.010000     -25.000000     45.0           904           0.398444
# 35    0.03  0.000000       0.000000    211.0          2142           0.427740
# 36    0.03 -0.010000     -33.333336     10.0           858           0.468755
# 37    0.02 -0.010000     -33.333336    102.0           413           0.488286
# 38    0.02  0.000000       0.000000    432.0          1549           0.507817
# 39    0.02  0.000000       0.000000     42.0           451           0.531255
# 40    0.02 -0.010000     -50.000000     10.0           531           0.562504
# 41    0.01  0.000000       0.000000    352.0           125           0.562504
# 42    0.01  0.000000       0.000000    612.0          1742           0.593754
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8         True      REGULAR      USD
# 9         True      REGULAR      USD
# 10        True      REGULAR      USD
# 11        True      REGULAR      USD
# 12        True      REGULAR      USD
# 13        True      REGULAR      USD
# 14        True      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24       False      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31       False      REGULAR      USD
# 32       False      REGULAR      USD
# 33       False      REGULAR      USD
# 34       False      REGULAR      USD
# 35       False      REGULAR      USD
# 36       False      REGULAR      USD
# 37       False      REGULAR      USD
# 38       False      REGULAR      USD
# 39       False      REGULAR      USD
# 40       False      REGULAR      USD
# 41       False      REGULAR      USD
# 42       False      REGULAR      USD  , puts=         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL240705P00100000 2024-06-24 14:12:45+00:00   100.0       0.01   0.00
# 1   AAPL240705P00115000 2024-06-20 14:00:12+00:00   115.0       0.01   0.00
# 2   AAPL240705P00120000 2024-06-12 15:47:03+00:00   120.0       0.01   0.00
# 3   AAPL240705P00125000 2024-06-13 13:34:38+00:00   125.0       0.03   0.00
# 4   AAPL240705P00135000 2024-06-24 13:30:00+00:00   135.0       0.03   0.00
# 5   AAPL240705P00140000 2024-06-14 15:07:10+00:00   140.0       0.02   0.00
# 6   AAPL240705P00145000 2024-06-18 16:04:20+00:00   145.0       0.02   0.00
# 2    0.01  0.000000       0.000000      NaN             1           1.031255
# 3    0.01  0.000000       0.000000      3.0             3           0.968750
# 4    0.01  0.000000       0.000000     74.0            79           0.843752
# 5    0.12  0.000000       0.000000      3.0            27           0.980469
# 6    0.02  0.000000       0.000000      2.0             5           0.750003
# 7    0.01  0.000000       0.000000      1.0            37           0.656253
# 8    0.02  0.000000       0.000000      1.0            11           0.625004
# 9    0.02  0.010000     100.000000      6.0           294           0.562504
# 10   0.02  0.000000       0.000000    321.0           162           0.500005
# 11   0.02 -0.010000     -50.000000     47.0           927           0.476568
# 12   0.04 -0.010000     -25.000000      7.0           782           0.449224
# 13   0.04 -0.010000     -25.000000    180.0          2328           0.386725
# 14   0.06 -0.020000     -28.571428    217.0          2572           0.341803
# 15   0.08 -0.030000     -33.333336    168.0           736           0.322272
# 16   0.10 -0.040000     -30.769224    310.0          4712           0.298835
# 17   0.13 -0.050000     -27.777782    103.0          2187           0.276374
# 18   0.17 -0.070000     -30.434786    983.0          4834           0.253425
# 19   0.25 -0.080000     -24.242426    454.0           792           0.234871
# 20   0.39 -0.200000     -35.714283   3828.0          5800           0.218025
# 21   0.66 -0.290000     -32.584267   1447.0          1358           0.206063
# 22   1.10 -0.420000     -28.378384   3642.0          5335           0.194100
# 23   1.89 -0.610000     -25.416672   7785.0          3834           0.189095
# 24   3.05 -0.800000     -21.857927  13185.0          6150           0.184945
# 25   4.60 -0.840000     -15.730339   1155.0          1192           0.181283
# 26   6.50 -1.200000     -15.999998    328.0          2101           0.177743
# 27   8.75 -0.850000      -8.947372     60.0           647           0.187752
# 28  11.10 -0.770000      -7.264155    281.0           849           0.195321
# 29  14.05 -0.670000      -5.056604     10.0            83           0.312507
# 30  16.55  0.400001       2.589001     13.0            26           0.351325
# 31  19.10  1.910000      12.330535      2.0             3           0.396735
# 32  21.15  0.469999       2.379743     27.0            10           0.337897
# 33  24.05  0.000000       0.000000      NaN             0           0.459722
# 34  26.55  0.000000       0.000000      1.0             1           0.493657
# 35  31.45  0.000000       0.000000      3.0             4           0.537602
# 36  36.55  0.000000       0.000000     57.0             1           0.621586
# 37  41.45  0.000000       0.000000     11.0             0           0.657230
# 38  51.55  0.000000       0.000000      2.0             0           0.794924
# 39  56.55  0.000000       0.000000      1.0             0           0.848146
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18       False      REGULAR      USD
# 19       False      REGULAR      USD
# 20       False      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24        True      REGULAR      USD
# 25        True      REGULAR      USD
# 26        True      REGULAR      USD
# 27        True      REGULAR      USD
# 28        True      REGULAR      USD
# 29        True      REGULAR      USD
# 30        True      REGULAR      USD
# 31        True      REGULAR      USD
# 32        True      REGULAR      USD
# 33        True      REGULAR      USD
# 34        True      REGULAR      USD
# 35        True      REGULAR      USD
# 36        True      REGULAR      USD
# 37        True      REGULAR      USD
# 38        True      REGULAR      USD
# 39        True      REGULAR      USD  , underlying={'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'currency': 'USD', 'marketState': 'POSTPOST', 'regularMarketChangePercent': 0.44681844, 'regularMarketPrice': 209.07, 'exchange': 'NMS', 'shortName': 'Apple Inc.', 'longName': 'Apple Inc.', 'messageBoardId': 'finmb_24937', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'gmtOffSetMilliseconds': -14400000, 'market': 'us_market', 'esgPopulated': False, 'hasPrePostMarketData': True, 'firstTradeDateMilliseconds': 345479400000, 'priceHint': 2, 'postMarketChangePercent': 0.0143487, 'postMarketTime': 1719359998, 'postMarketPrice': 209.1, 'postMarketChange': 0.0299988, 'regularMarketChange': 0.93000793, 'regularMarketTime': 1719345601, 'regularMarketDayHigh': 211.38, 'regularMarketDayRange': '208.61 - 211.38', 'regularMarketDayLow': 208.61, 'regularMarketVolume': 56267620, 'regularMarketPreviousClose': 208.14, 'bid': 209.16, 'ask': 209.3, 'bidSize': 1, 'askSize': 1, 'fullExchangeName': 'NasdaqGS', 'financialCurrency': 'USD', 'regularMarketOpen': 209.08, 'averageDailyVolume3Month': 68294093, 'averageDailyVolume10Day': 122265030, 'fiftyTwoWeekLowChange': 44.990005, 'fiftyTwoWeekLowChangePercent': 0.27419555, 'fiftyTwoWeekRange': '164.08 - 220.2', 'fiftyTwoWeekHighChange': -11.12999, 'fiftyTwoWeekHighChangePercent': -0.050544914, 'fiftyTwoWeekLow': 164.08, 'fiftyTwoWeekHigh': 220.2, 'fiftyTwoWeekChangePercent': 10.677444, 'dividendDate': 1715817600, 'earningsTimestamp': 1714681800, 'earningsTimestampStart': 1722509940, 'earningsTimestampEnd': 1722859200, 'earningsCallTimestampStart': 1714683600, 'earningsCallTimestampEnd': 1714683600, 'isEarningsDateEstimate': True, 'trailingAnnualDividendRate': 0.96, 'trailingPE': 32.51478, 'dividendRate': 1.0, 'trailingAnnualDividendYield': 0.00461228, 'dividendYield': 0.48, 'epsTrailingTwelveMonths': 6.43, 'epsForward': 6.81, 'epsCurrentYear': 6.17, 'priceEpsCurrentYear': 33.88493, 'sharesOutstanding': 15334099968, 'bookValue': 4.837, 'fiftyDayAverage': 187.4738, 'fiftyDayAverageChange': 21.596207, 'fiftyDayAverageChangePercent': 0.11519586, 'twoHundredDayAverage': 183.01765, 'twoHundredDayAverageChange': 26.052353, 'twoHundredDayAverageChangePercent': 0.14234886, 'marketCap': 3205900271616, 'forwardPE': 30.700441, 'priceToBook': 43.223076, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'averageAnalystRating': '2.0 - Buy', 'tradeable': False, 'cryptoTradeable': False, 'displayName': 'Apple', 'symbol': 'AAPL'})

# %%
data = yf.download('TQQQ', start = '2000-01-01', end = '2024-01-01')
data['Day'] = data.index.day_of_week
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2010-02-11   0.406875   0.434896   0.405573   0.432552   0.418944   3456000
# 2010-02-12   0.420781   0.438073   0.418333   0.434323   0.420659   8601600
# 2010-02-16   0.444531   0.452188   0.437552   0.451146   0.436953   9619200
# 2010-02-17   0.457188   0.458906   0.450313   0.458802   0.444368  19180800
# 2010-02-18   0.458333   0.470260   0.455573   0.467500   0.452793  38860800
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-22  50.599998  50.939999  49.639999  50.349998  49.977837  66114200
# 2023-12-26  50.639999  51.509998  50.619999  51.270000  50.891037  43685600
# 2023-12-27  51.349998  51.660000  51.020000  51.540001  51.159039  55747800
# 2023-12-28  51.919998  52.009998  51.270000  51.410000  51.030003  42884100
# 2023-12-29  51.380001  51.520000  50.000000  50.700001  50.325249  66986200
#
#             Day
# Date
# 2010-02-11    3
# 2010-02-12    4
# 2010-02-16    1
# 2010-02-17    2
# 2010-02-18    3
# ...         ...
# 2023-12-22    4
# 2023-12-26    1
# 2023-12-27    2
# 2023-12-28    3
# 2023-12-29    4
#
# [3495 rows x 7 columns]

# %%
'''
Strategy:
Buy: On Tuesday or Wednesday, if the two previous days have consecutively lower closing prices, long at the open
Sell: When the close is higher than the previous day's high, sell at the close
'''
buys = []
sells = []
index = []
position = False
for i in range(len(data)):
    if data['Day'][i] == 1 or data['Day'][i] == 2:
        if i > 2 and data['Close'][i-1] < data['Close'][i-2]:
            if data['Close'][i-2] < data['Close'][i-3] and position == False:
                buys.append(data['Open'][i])
                position = True
                index.append(i)
    if position == True:
        if i > index[-1] and data['Close'][i] > data['High'][i-1]:
            sells.append(data['Close'][i])
            position = False
# Out:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_38624\1119441558.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data['Day'][i] == 1 or data['Day'][i] == 2:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_38624\1119441558.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i > 2 and data['Close'][i-1] < data['Close'][i-2]:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_38624\1119441558.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if data['Close'][i-2] < data['Close'][i-3] and position == False:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_38624\1119441558.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   buys.append(data['Open'][i])
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_38624\1119441558.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i > index[-1] and data['Close'][i] > data['High'][i-1]:
# C:\Users\ryanl\AppData\Local\Temp\ipykernel_38624\1119441558.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sells.append(data['Close'][i])

# %%
#Calculate the annualized returns of the strategy
returns = (np.array(sells) - np.array(buys)) / np.array(buys)
cumulative_return = np.prod(1 + returns) - 1
total_days = len(data)
annualized_return = (1 + cumulative_return) ** (365 / total_days) - 1
print("Annualized Return: " + str(round(annualized_return * 100, 2)), "%")
# Out:
# Annualized Return: 30.74 %

# %%
# Out:
# Sharpe Ratio: -5.7675
